# %%
Módulo2-Notas
Curso: Data Analysis with Python (IBM)
Materia: Ciencia y analítica de datos
Maximiliano Morones Gómez
Matrícula: A01793815

# %%
from PIL import Image 
import numpy as np
from matplotlib import pyplot as pit

# %%
im = Image.open('2.1.png')
print(im.format)
print(im.size)
print(im.mode)
im
# Out:
# PNG
# (2880, 1310)
# RGBA
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2880x1310>

# %%
im = Image.open('2.2.png')
print(im.format)
print(im.size)
print(im.mode)
im
# Out:
# PNG
# (2396, 1356)
# RGBA
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2396x1356>

# %%
im = Image.open('2.3.png')
print(im.format)
print(im.size)
print(im.mode)
im
# Out:
# PNG
# (2788, 1082)
# RGBA
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2788x1082>

# %%
im = Image.open('2.4.png')
print(im.format)
print(im.size)
print(im.mode)
im
# Out:
# PNG
# (1990, 930)
# RGBA
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1990x930>

# %%
im = Image.open('2.5.png')
print(im.format)
print(im.size)
print(im.mode)
im
# Out:
# PNG
# (1990, 818)
# RGBA
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1990x818>

# %%
im = Image.open('2.6.png')
print(im.format)
print(im.size)
print(im.mode)
im
# Out:
# PNG
# (1990, 934)
# RGBA
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1990x934>

# %%
im = Image.open('2.7.png')
print(im.format)
print(im.size)
print(im.mode)
im
# Out:
# PNG
# (2040, 974)
# RGBA
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2040x974>

# %%
im = Image.open('2.8.png')
print(im.format)
print(im.size)
print(im.mode)
im
# Out:
# PNG
# (2042, 1076)
# RGBA
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2042x1076>

# %%
im = Image.open('2.9.png')
print(im.format)
print(im.size)
print(im.mode)
im
# Out:
# PNG
# (1990, 1020)
# RGBA
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1990x1020>
