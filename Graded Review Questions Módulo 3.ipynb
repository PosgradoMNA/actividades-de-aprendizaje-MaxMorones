# %%
Módulo3-Notas
Curso: Data Analysis with Python (IBM)
Materia: Ciencia y analítica de datos
Maximiliano Morones Gómez
Matrícula: A01793815

# %%
from PIL import Image 
import numpy as np
from matplotlib import pyplot as pit

# %%
im = Image.open('3.1.png')
print(im.format)
print(im.size)
print(im.mode)
im
# Out:
# PNG
# (2880, 1180)
# RGBA
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2880x1180>

# %%
im = Image.open('3.2.png')
print(im.format)
print(im.size)
print(im.mode)
im
# Out:
# PNG
# (1686, 1356)
# RGBA
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1686x1356>

# %%
im = Image.open('3.3.png')
print(im.format)
print(im.size)
print(im.mode)
im
# Out:
# PNG
# (2880, 1220)
# RGBA
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2880x1220>

# %%
im = Image.open('3.4.png')
print(im.format)
print(im.size)
print(im.mode)
im
# Out:
# PNG
# (2846, 1054)
# RGBA
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2846x1054>

# %%
im = Image.open('3.5.png')
print(im.format)
print(im.size)
print(im.mode)
im
# Out:
# PNG
# (2846, 1256)
# RGBA
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2846x1256>

# %%
im = Image.open('3.6.png')
print(im.format)
print(im.size)
print(im.mode)
im
# Out:
# PNG
# (2880, 832)
# RGBA
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2880x832>

# %%
im = Image.open('3.7.png')
print(im.format)
print(im.size)
print(im.mode)
im
# Out:
# PNG
# (2880, 932)
# RGBA
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2880x932>

# %%
im = Image.open('3.8.png')
print(im.format)
print(im.size)
print(im.mode)
im
# Out:
# PNG
# (2878, 1184)
# RGBA
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2878x1184>
