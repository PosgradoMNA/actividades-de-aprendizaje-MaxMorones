# %%
Módulo4-Notas
Curso: Data Analysis with Python (IBM)
Materia: Ciencia y analítica de datos
Maximiliano Morones Gómez
Matrícula: A01793815

# %%
from PIL import Image 
import numpy as np
from matplotlib import pyplot as pit

# %%
im = Image.open('4.1.png')
print(im.format)
print(im.size)
print(im.mode)
im
# Out:
# PNG
# (2880, 1180)
# RGBA
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2880x1180>

# %%
im = Image.open('4.2.png')
print(im.format)
print(im.size)
print(im.mode)
im
# Out:
# PNG
# (2844, 1296)
# RGBA
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2844x1296>

# %%
im = Image.open('4.3.png')
print(im.format)
print(im.size)
print(im.mode)
im
# Out:
# PNG
# (2880, 1358)
# RGBA
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2880x1358>

# %%
im = Image.open('4.4.png')
print(im.format)
print(im.size)
print(im.mode)
im
# Out:
# PNG
# (2880, 1356)
# RGBA
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2880x1356>

# %%
im = Image.open('4.5.png')
print(im.format)
print(im.size)
print(im.mode)
im
# Out:
# PNG
# (2880, 1026)
# RGBA
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2880x1026>

# %%
im = Image.open('4.6.png')
print(im.format)
print(im.size)
print(im.mode)
im
# Out:
# PNG
# (2880, 968)
# RGBA
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2880x968>

# %%
im = Image.open('4.7.png')
print(im.format)
print(im.size)
print(im.mode)
im
# Out:
# PNG
# (2880, 836)
# RGBA
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2880x836>

# %%
im = Image.open('4.8.png')
print(im.format)
print(im.size)
print(im.mode)
im
# Out:
# PNG
# (2880, 1358)
# RGBA
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2880x1358>
