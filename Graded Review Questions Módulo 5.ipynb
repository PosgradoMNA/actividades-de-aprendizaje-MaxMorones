# %%
Módulo5-Notas
Curso: Data Analysis with Python (IBM)
Materia: Ciencia y analítica de datos
Maximiliano Morones Gómez
Matrícula: A01793815

# %%
from PIL import Image 
import numpy as np
from matplotlib import pyplot as pit

# %%
im = Image.open('5.1.png')
print(im.format)
print(im.size)
print(im.mode)
im
# Out:
# PNG
# (2880, 1186)
# RGBA
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2880x1186>

# %%
im = Image.open('5.2.png')
print(im.format)
print(im.size)
print(im.mode)
im
# Out:
# PNG
# (2846, 1234)
# RGBA
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2846x1234>

# %%
im = Image.open('5.3.png')
print(im.format)
print(im.size)
print(im.mode)
im
# Out:
# PNG
# (2880, 1360)
# RGBA
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2880x1360>

# %%
im = Image.open('5.4.png')
print(im.format)
print(im.size)
print(im.mode)
im
# Out:
# PNG
# (2880, 1362)
# RGBA
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2880x1362>

# %%
im = Image.open('5.5.png')
print(im.format)
print(im.size)
print(im.mode)
im
# Out:
# PNG
# (2880, 740)
# RGBA
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2880x740>

# %%
im = Image.open('5.6.png')
print(im.format)
print(im.size)
print(im.mode)
im
# Out:
# PNG
# (2880, 724)
# RGBA
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2880x724>

# %%
im = Image.open('5.7.png')
print(im.format)
print(im.size)
print(im.mode)
im
# Out:
# PNG
# (2878, 674)
# RGBA
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2878x674>

# %%
im = Image.open('5.8.png')
print(im.format)
print(im.size)
print(im.mode)
im
# Out:
# PNG
# (2880, 1196)
# RGBA
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2880x1196>
