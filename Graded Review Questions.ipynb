# %%
Módulo1-Notas
Curso: Data Analysis with Python (IBM)
Materia: Ciencia y analítica de datos
Maximiliano Morones Gómez
Matrícula: A01793815

# %%
from PIL import Image 
import numpy as np
from matplotlib import pyplot as pit

# %%
im = Image.open('1.png')
print(im.format)
print(im.size)
print(im.mode)
im
# Out:
# PNG
# (2880, 1360)
# RGBA
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2880x1360>

# %%
im = Image.open('2.png')
print(im.format)
print(im.size)
print(im.mode)
im
# Out:
# PNG
# (2880, 1316)
# RGBA
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2880x1316>

# %%
im = Image.open('3.png')
print(im.format)
print(im.size)
print(im.mode)
im
# Out:
# PNG
# (2880, 356)
# RGBA
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2880x356>

# %%
im = Image.open('4.png')
print(im.format)
print(im.size)
print(im.mode)
im
# Out:
# PNG
# (2880, 1212)
# RGBA
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2880x1212>

# %%
im = Image.open('5.png')
print(im.format)
print(im.size)
print(im.mode)
im
# Out:
# PNG
# (1924, 1062)
# RGBA
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1924x1062>

# %%
im = Image.open('6.png')
print(im.format)
print(im.size)
print(im.mode)
im
# Out:
# PNG
# (1934, 1360)
# RGBA
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1934x1360>

# %%
im = Image.open('7.png')
print(im.format)
print(im.size)
print(im.mode)
im
# Out:
# PNG
# (2006, 1096)
# RGBA
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2006x1096>
